# %%
import pandas as pd
import pickle

# %%
with open("..\\data_vis\\progress\\tsne\\519.pkl", "rb") as f:
    df = pickle.load(f)

# %%
df = pd.concat(df)

# %%
df.head(4)
# Out:
#           X         Y                                            caption  \
# 0  0.242387  0.263043  [-0.0024316765, 0.015905945, 0.011367992, 0.01...
# 1  0.453534  0.309793  [0.013644677, -0.013433643, 0.018261889, -0.00...
# 2  0.254215  0.816617  [0.013936427, 0.0062423013, -0.026340615, 0.00...
# 3  0.449136  0.640177  [0.024949268, 0.017259138, 0.012959479, -0.016...
#
#   img_id
# 0    510
# 1    510
# 2    510
# 3    510

# %%
df.reset_index(inplace=True)

# %%
fil = df[df['img_id'] == "510"]

# %%
fil
# Out:
#       index         X         Y  \
# 0         0  0.242387  0.263043
# 1         1  0.453534  0.309793
# 2         2  0.254215  0.816617
# 3         3  0.449136  0.640177
# 4         4  0.533865  0.685779
# ...     ...       ...       ...
# 3900   3900  0.396394  0.389968
# 3901   3901  0.363275  0.603665
# 3902   3902  0.475473  0.514012
# 3903   3903  0.604422  0.719809
# 3904   3904  0.458761  0.063929
#
#                                                 caption img_id
# 0     [-0.0024316765, 0.015905945, 0.011367992, 0.01...    510
# 1     [0.013644677, -0.013433643, 0.018261889, -0.00...    510
# 2     [0.013936427, 0.0062423013, -0.026340615, 0.00...    510
# 3     [0.024949268, 0.017259138, 0.012959479, -0.016...    510
# 4     [0.017066576, 0.027702745, -0.015552021, -0.02...    510
# ...                                                 ...    ...
# 3900  [0.0120331105, -0.015283984, 0.0011412072, 0.0...    510
# 3901  [-0.0134234335, 0.036359474, 0.0142259905, 0.0...    510
# ...

# %%
fil
# Out:
#       index         X         Y  \
# 0         0  0.242387  0.263043
# 1         1  0.453534  0.309793
# 2         2  0.254215  0.816617
# 3         3  0.449136  0.640177
# 4         4  0.533865  0.685779
# ...     ...       ...       ...
# 3900   3900  0.396394  0.389968
# 3901   3901  0.363275  0.603665
# 3902   3902  0.475473  0.514012
# 3903   3903  0.604422  0.719809
# 3904   3904  0.458761  0.063929
#
#                                                 caption img_id
# 0     [-0.0024316765, 0.015905945, 0.011367992, 0.01...    510
# 1     [0.013644677, -0.013433643, 0.018261889, -0.00...    510
# 2     [0.013936427, 0.0062423013, -0.026340615, 0.00...    510
# 3     [0.024949268, 0.017259138, 0.012959479, -0.016...    510
# 4     [0.017066576, 0.027702745, -0.015552021, -0.02...    510
# ...                                                 ...    ...
# 3900  [0.0120331105, -0.015283984, 0.0011412072, 0.0...    510
# 3901  [-0.0134234335, 0.036359474, 0.0142259905, 0.0...    510
# ...
